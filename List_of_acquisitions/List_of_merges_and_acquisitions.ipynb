# %%
import pandas as pd 
import matplotlib as plt 
import seaborn as sns 
sns.set()

# %%
df = pd.read_csv("List_of_mergers_and_acquisitions_by_Amazon.csv")
df
# Out:
#      Company_name Company_Country  \
# 0       Bookpages  United Kingdom
# 1        Telebook         Germany
# 2            IMDb  United Kingdom
# 3         Junglee   United States
# 4       PlanetAll   United States
# ..            ...             ...
# 109      GlowRoad           India
# 110   One Medical   United States
# 111        iRobot   United States
# 112  Cloostermans         Belgium
# 113     Spirit.ai  United Kingdom
#
#                               Company_Country_url Company_Acquired_on  \
# 0    https://en.wikipedia.org/wiki/United_Kingdom      April 27, 1998
# 1           https://en.wikipedia.org/wiki/Germany      April 27, 1998
# 2    https://en.wikipedia.org/wiki/United_Kingdom      April 27, 1998
# 3     https://en.wikipedia.org/wiki/United_States      August 4, 1998
# 4     https://en.wikipedia.org/wiki/United_States      August 4, 1998
# ..                                            ...                 ...
# ...

# %%
df.describe()
# Out:
#        Company_name Company_Country  \
# count           114             114
# unique          114              16
# top       Bookpages   United States
# freq              1              82
#
#                                 Company_Country_url Company_Acquired_on  \
# count                                           114                 113
# unique                                           16                 106
# top     https://en.wikipedia.org/wiki/United_States      April 27, 1998
# freq                                             82                   3
#
#        Company_Acquired_for      Company_Used_as
# count                   113                   86
# unique                   38                   56
# top                       —  Amazon Web Services
# freq                     69                   16

# %%
df.dtypes
# Out:
# Company_name            object
# Company_Country         object
# Company_Country_url     object
# Company_Acquired_on     object
# Company_Acquired_for    object
# Company_Used_as         object
# dtype: object

# %%
df.sort_values('Company_Acquired_for', ascending = False)
# Out:
#       Company_name       Company_Country  \
# 56          Amiato         United States
# 58   Rooftop Media         United States
# 69     Colis Privé                France
# 68          Orbeus         United States
# 67    Biba Systems         United States
# ..             ...                   ...
# 111         iRobot         United States
# 101           Zoox         United States
# 34          Zappos         United States
# 83         Wing.ae  United Arab Emirates
# 112   Cloostermans               Belgium
#
#                                    Company_Country_url Company_Acquired_on  \
# 56         https://en.wikipedia.org/wiki/United_States            May 2014
# 58         https://en.wikipedia.org/wiki/United_States     August 25, 2014
# 69                https://en.wikipedia.org/wiki/France    January 11, 2016
# 68         https://en.wikipedia.org/wiki/United_States    December 1, 2015
# 67         https://en.wikipedia.org/wiki/United_States      September 2015
# ...

# %%
df['Company_Country'].value_counts()
# Out:
# United States           82
# United Kingdom          10
# India                    4
# Israel                   3
# France                   2
# Canada                   2
# United Arab Emirates     2
# Germany                  1
# China                    1
# Spain                    1
# Poland                   1
# Netherlands              1
# Italy                    1
# Sweden                   1
# Finland                  1
# Belgium                  1
# Name: Company_Country, dtype: int64

# %%
df['Company_Used_as'].value_counts()
# Out:
# Amazon Web Services                16
# Twitch Interactive                  5
# Amazon Robotics                     3
# Amazon Echo                         3
# Amazon Kindle                       3
# Audible                             2
# Souq.com                            2
# Goodreads                           2
# Amazon Music                        2
# CreateSpace                         2
# Amazon Pharmacy                     1
# Westland                            1
# ComiXology                          1
# Metro-Goldwyn-Mayer                 1
# Eero                                1
# Annapurna Labs                      1
# AWS Elemental                       1
# Amazon Chime                        1
# Curse LLC                           1
# Whole Foods Market                  1
# Ring                                1
# TSOLogic                            1
# GameSparks                          1
# Amazon Echo, Amazon Polly           1
# Body Labs                           1
# ...
