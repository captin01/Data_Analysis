# %% [markdown]
# # WEATHER DATA
# - analysis using pandas

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()

# %%
W_data = pd.read_csv("Weather_Data.csv")
W_data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
W_data.shape
# Out:
# (8784, 8)

# %%
W_data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
W_data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %% [markdown]
# - changing Date (object) to date/time

# %%
W_data['Date/Time'] = pd.to_datetime(W_data['Date/Time'])

# %%
W_data.dtypes
# Out:
# Date/Time           datetime64[ns]
# Temp_C                     float64
# Dew Point Temp_C           float64
# Rel Hum_%                    int64
# Wind Speed_km/h              int64
# Visibility_km              float64
# Press_kPa                  float64
# Weather                     object
# dtype: object

# %% [markdown]
# - finding Unique values in the weather column

# %%
W_data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %% [markdown]
# - Finding no. of unique values in each column

# %%
W_data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
W_data.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# - No of times unique values in weather column have appeared.

# %%
W_data['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
W_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   datetime64[ns]
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 549.1+ KB

# %% [markdown]
# - Unique (wind Speed) values

# %%
W_data['Wind Speed_km/h']
# Out:
# 0        4
# 1        4
# 2        7
# 3        6
# 4        7
#         ..
# 8779    30
# 8780    24
# 8781    28
# 8782    28
# 8783    30
# Name: Wind Speed_km/h, Length: 8784, dtype: int64

# %%
W_data['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
W_data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %% [markdown]
# - no. of times the weather was clear

# %%
W_data[W_data.Weather == 'Clear']
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 67   2012-01-03 19:00:00   -16.9             -24.8         50
# 114  2012-01-05 18:00:00    -7.1             -14.4         56
# 115  2012-01-05 19:00:00    -9.2             -15.4         61
# 116  2012-01-05 20:00:00    -9.8             -15.7         62
# 117  2012-01-05 21:00:00    -9.0             -14.8         63
# ...                  ...     ...               ...        ...
# 8646 2012-12-26 06:00:00   -13.4             -14.8         89
# 8698 2012-12-28 10:00:00    -6.1              -8.6         82
# 8713 2012-12-29 01:00:00   -11.9             -13.6         87
# 8714 2012-12-29 02:00:00   -11.8             -13.1         90
# 8756 2012-12-30 20:00:00   -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather
# 67                 24           25.0     101.74   Clear
# 114                11           25.0     100.71   Clear
# ...

# %% [markdown]
# - no. of times wind-speed was(4km/h)

# %%
W_data[W_data['Wind Speed_km/h'] == 4]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 96   2012-01-05 00:00:00    -8.8             -11.7         79
# 101  2012-01-05 05:00:00    -7.0              -9.5         82
# 146  2012-01-07 02:00:00    -8.1             -11.1         79
# ...                  ...     ...               ...        ...
# 8768 2012-12-31 08:00:00    -8.6             -10.3         87
# 8769 2012-12-31 09:00:00    -8.1              -9.6         89
# 8770 2012-12-31 10:00:00    -7.4              -8.9         89
# 8772 2012-12-31 12:00:00    -5.8              -7.5         88
# 8773 2012-12-31 13:00:00    -4.6              -6.6         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa       Weather
# 0                   4            8.0     101.24           Fog
# 1                   4            8.0     101.24           Fog
# ...

# %% [markdown]
# - no. of null values in the data

# %%
W_data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# - rename (Weather) column to (Weather_conditions) & (Wind Speed_Km/h) to (Wind_speed_Km/h)

# %%
W_data.rename(columns= {'Weather' : 'Weather_conditions'}, inplace= True)
W_data.rename(columns= {'Wind Speed_km/h' : 'Wind_speed_Km/h'}, inplace= True)

# %%
W_data.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_speed_Km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather_conditions
# 0            8.0     101.24                Fog
# 1            8.0     101.24                Fog

# %% [markdown]
# - mean of visibility

# %%
W_data.Visibility_km.describe()
# Out:
# count    8784.000000
# mean       27.664447
# std        12.622688
# min         0.200000
# 25%        24.100000
# 50%        25.000000
# 75%        25.000000
# max        48.300000
# Name: Visibility_km, dtype: float64

# %% [markdown]
# - std() of the pressure column

# %%
W_data.Press_kPa.std()
# Out:
# 0.8440047459486474

# %% [markdown]
# - finding variance of the humidity

# %%
W_data['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %% [markdown]
# - finding instances when snow was recorded

# %%
W_data.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_speed_Km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather_conditions
# 0            8.0     101.24                Fog
# 1            8.0     101.24                Fog

# %%
W_data[W_data.Weather_conditions == 'Snow']
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 55   2012-01-03 07:00:00   -14.0             -19.5         63
# 84   2012-01-04 12:00:00   -13.7             -21.7         51
# 86   2012-01-04 14:00:00   -11.3             -19.0         53
# 87   2012-01-04 15:00:00   -10.2             -16.3         61
# 88   2012-01-04 16:00:00    -9.4             -15.5         61
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind_speed_Km/h  Visibility_km  Press_kPa Weather_conditions
# 55                 19           25.0     100.95               Snow
# 84                 11           24.1     101.25               Snow
# ...

# %%
W_data[W_data.Weather_conditions.str.contains('Snow')].head(20)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_speed_Km/h  \
# 41 2012-01-02 17:00:00    -2.1              -9.5         57               22
# 44 2012-01-02 20:00:00    -5.6             -13.4         54               24
# 45 2012-01-02 21:00:00    -5.8             -12.8         58               26
# 47 2012-01-02 23:00:00    -7.4             -14.1         59               17
# 48 2012-01-03 00:00:00    -9.0             -16.0         57               28
# 50 2012-01-03 02:00:00   -10.5             -15.8         65               22
# 51 2012-01-03 03:00:00   -11.3             -18.7         54               33
# 53 2012-01-03 05:00:00   -12.9             -19.1         60               22
# 54 2012-01-03 06:00:00   -13.3             -19.3         61               19
# 55 2012-01-03 07:00:00   -14.0             -19.5         63               19
# 84 2012-01-04 12:00:00   -13.7             -21.7         51               11
# ...

# %% [markdown]
# - Using multiple filters

# %%
W_data[(W_data['Wind_speed_Km/h'] > 24) & (W_data['Visibility_km'] == 25)]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 23   2012-01-01 23:00:00     5.3               2.0         79
# 24   2012-01-02 00:00:00     5.2               1.5         77
# 25   2012-01-02 01:00:00     4.6               0.0         72
# 26   2012-01-02 02:00:00     3.9              -0.9         71
# 27   2012-01-02 03:00:00     3.7              -1.5         69
# ...                  ...     ...               ...        ...
# 8705 2012-12-28 17:00:00    -8.6             -12.0         76
# 8753 2012-12-30 17:00:00   -12.1             -15.8         74
# 8755 2012-12-30 19:00:00   -13.4             -16.5         77
# 8759 2012-12-30 23:00:00   -12.1             -15.1         78
# 8760 2012-12-31 00:00:00   -11.1             -14.4         77
#
#       Wind_speed_Km/h  Visibility_km  Press_kPa Weather_conditions
# 23                 30           25.0      99.31             Cloudy
# 24                 35           25.0      99.26       Rain Showers
# ...

# %% [markdown]
# - finding mean of Df using .groupby('Weather_conditions')

# %%
W_data.groupby('Weather_conditions').mean()
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather_conditions
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %%
W_data.groupby('Weather_conditions').min()
# Out:
#                                                   Date/Time  Temp_C  \
# Weather_conditions
# Clear                                   2012-01-03 19:00:00   -23.3
# Cloudy                                  2012-01-01 17:00:00   -21.4
# Drizzle                                 2012-01-23 21:00:00     1.1
# Drizzle,Fog                             2012-01-23 20:00:00     0.0
# Drizzle,Ice Pellets,Fog                 2012-12-17 09:00:00     0.4
# Drizzle,Snow                            2012-12-17 15:00:00     0.9
# Drizzle,Snow,Fog                        2012-12-18 21:00:00     0.3
# Fog                                     2012-01-01 00:00:00   -16.0
# Freezing Drizzle                        2012-01-07 11:00:00    -9.0
# Freezing Drizzle,Fog                    2012-01-01 02:00:00    -6.4
# Freezing Drizzle,Haze                   2012-02-01 11:00:00    -5.8
# Freezing Drizzle,Snow                   2012-01-13 03:00:00    -8.3
# ...

# %%
W_data.groupby('Weather_conditions').max()
# Out:
#                                                   Date/Time  Temp_C  \
# Weather_conditions
# Clear                                   2012-12-30 20:00:00    32.8
# Cloudy                                  2012-12-31 06:00:00    30.5
# Drizzle                                 2012-12-22 01:00:00    18.8
# Drizzle,Fog                             2012-12-19 10:00:00    19.9
# Drizzle,Ice Pellets,Fog                 2012-12-17 09:00:00     0.4
# Drizzle,Snow                            2012-12-19 18:00:00     1.2
# Drizzle,Snow,Fog                        2012-12-22 03:00:00     1.1
# Fog                                     2012-12-29 10:00:00    20.8
# Freezing Drizzle                        2012-12-17 00:00:00    -2.3
# Freezing Drizzle,Fog                    2012-12-10 05:00:00    -0.3
# Freezing Drizzle,Haze                   2012-02-01 13:00:00    -5.0
# Freezing Drizzle,Snow                   2012-12-28 02:00:00    -3.3
# ...

# %% [markdown]
# - show instances where weather_conditions = clear OR visibility > 40

# %%
W_data[(W_data['Weather_conditions'] == 'Clear') | (W_data['Visibility_km'] > 40)]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 67   2012-01-03 19:00:00   -16.9             -24.8         50
# 106  2012-01-05 10:00:00    -6.0             -10.0         73
# 107  2012-01-05 11:00:00    -5.6             -10.2         70
# 108  2012-01-05 12:00:00    -4.7              -9.6         69
# 109  2012-01-05 13:00:00    -4.4              -9.7         66
# ...                  ...     ...               ...        ...
# 8749 2012-12-30 13:00:00   -12.4             -16.2         73
# 8750 2012-12-30 14:00:00   -11.8             -16.1         70
# 8751 2012-12-30 15:00:00   -11.3             -15.6         70
# 8752 2012-12-30 16:00:00   -11.4             -15.5         72
# 8756 2012-12-30 20:00:00   -13.8             -16.5         80
#
#       Wind_speed_Km/h  Visibility_km  Press_kPa Weather_conditions
# 67                 24           25.0     101.74              Clear
# 106                17           48.3     100.45       Mainly Clear
# ...

# %% [markdown]
# - Find instances where weather_conditions = clear and Humidity > 50 OR Visibility > 50

# %%
W_data[(W_data['Weather_conditions'] == 'Clear') & (W_data['Rel Hum_%'] > 50) | (W_data['Visibility_km'] > 40)]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 106  2012-01-05 10:00:00    -6.0             -10.0         73
# 107  2012-01-05 11:00:00    -5.6             -10.2         70
# 108  2012-01-05 12:00:00    -4.7              -9.6         69
# 109  2012-01-05 13:00:00    -4.4              -9.7         66
# 110  2012-01-05 14:00:00    -5.1             -10.7         65
# ...                  ...     ...               ...        ...
# 8749 2012-12-30 13:00:00   -12.4             -16.2         73
# 8750 2012-12-30 14:00:00   -11.8             -16.1         70
# 8751 2012-12-30 15:00:00   -11.3             -15.6         70
# 8752 2012-12-30 16:00:00   -11.4             -15.5         72
# 8756 2012-12-30 20:00:00   -13.8             -16.5         80
#
#       Wind_speed_Km/h  Visibility_km  Press_kPa Weather_conditions
# 106                17           48.3     100.45       Mainly Clear
# 107                22           48.3     100.41       Mainly Clear
# ...

# %%
W_data.head(10)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_speed_Km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4 2012-01-01 04:00:00    -1.5              -3.3         88                7
# 5 2012-01-01 05:00:00    -1.4              -3.3         87                9
# 6 2012-01-01 06:00:00    -1.5              -3.1         89                7
# 7 2012-01-01 07:00:00    -1.4              -3.6         85                7
# 8 2012-01-01 08:00:00    -1.4              -3.6         85                9
# 9 2012-01-01 09:00:00    -1.3              -3.1         88               15
#
#    Visibility_km  Press_kPa    Weather_conditions
# 0            8.0     101.24                   Fog
# ...

# %%
W_data.corr()
# Out:
#                     Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_speed_Km/h  \
# Temp_C            1.000000          0.932714  -0.220182        -0.061876
# Dew Point Temp_C  0.932714          1.000000   0.139494        -0.095685
# Rel Hum_%        -0.220182          0.139494   1.000000        -0.092743
# Wind_speed_Km/h  -0.061876         -0.095685  -0.092743         1.000000
# Visibility_km     0.273455          0.050813  -0.633683         0.004883
# Press_kPa        -0.236389         -0.320616  -0.231424        -0.356613
#
#                   Visibility_km  Press_kPa
# Temp_C                 0.273455  -0.236389
# Dew Point Temp_C       0.050813  -0.320616
# Rel Hum_%             -0.633683  -0.231424
# Wind_speed_Km/h        0.004883  -0.356613
# Visibility_km          1.000000   0.231847
# Press_kPa              0.231847   1.000000

# %%
plt.figure(figsize = (12,6))
sns.heatmap(W_data.corr(), annot = True, cmap = "YlGnBu")
plt.show()
