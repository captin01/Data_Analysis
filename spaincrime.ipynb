# %%
import pandas as pd 
import numpy as np

# %%
s_data = pd.read_csv('crime_rate_Spain.csv')
s_data.head(10)
# Out:
#     Location  Year                                              Crime  \
# 0  Barcelona  2021      Intentional homicides and consummated murders
# 1  Barcelona  2021        Intentional homicides and attempted murders
# 2  Barcelona  2021  Serious and less serious crimes of injuries an...
# 3  Barcelona  2021                                         Kidnapping
# 4  Barcelona  2021        Crimes against freedom and sexual indemnity
# 5  Barcelona  2021                    Sexual assault with penetration
# 6  Barcelona  2021  Other crimes against freedom and sexual indemnity
# 7  Barcelona  2021             Robbery with violence and intimidation
# 8  Barcelona  2021                     Burglaries with force in homes
# 9  Barcelona  2021                      Robberies with force in homes
#
#    Total cases
# 0           36
# 1          137
# 2         2161
# 3            8
# 4         2406
# 5          436
# 6         1970
# 7        18360
# 8        16743
# 9        10697

# %%
s_data.head(10)
# Out:
#     Location  Year                                              Crime  \
# 0  Barcelona  2021      Intentional homicides and consummated murders
# 1  Barcelona  2021        Intentional homicides and attempted murders
# 2  Barcelona  2021  Serious and less serious crimes of injuries an...
# 3  Barcelona  2021                                         Kidnapping
# 4  Barcelona  2021        Crimes against freedom and sexual indemnity
# 5  Barcelona  2021                    Sexual assault with penetration
# 6  Barcelona  2021  Other crimes against freedom and sexual indemnity
# 7  Barcelona  2021             Robbery with violence and intimidation
# 8  Barcelona  2021                     Burglaries with force in homes
# 9  Barcelona  2021                      Robberies with force in homes
#
#    Total cases
# 0           36
# 1          137
# 2         2161
# 3            8
# 4         2406
# 5          436
# 6         1970
# 7        18360
# 8        16743
# 9        10697
